# %% [markdown]
# # Defining Probability

# %% [markdown]
# **Random Process**
#
# A random process occurs when we know what outcomes could happen, but we don't know which particular outcome will happen. For example, in a music player, when you hit shuffle on your music player you know what the possible outcomes are. The next song will be something from your entire music library, but you don't know which song will play next.
#
# **Notation**
#
# When discussing probabilities of events, we will generally use the notation ``P(A)`` to indicate the probability of event A. There are several possible interpretations of probability but they almost completely agree on the mathematical rules probability must follow. One of which is that probability of an event is always between 0 and 1.
#
# $$
# 0 \leq P(A) \leq 1
# $$
#
# ### Interpretation
#
# - **Frequentist Interpretation**
#
# In a frequentist interpretation of probability, i.e., a definition relative to the frequency, the probability of an outcome is the proportion of the times the outcome would occur if we observed the random process an infinite number of times.
#
# - **Bayesian Interpretation**
#
# A Bayesian interprets a probability as a subjective degree of belief. Thus, for the same event, two separate people could have different viewpoints and so assign different probabilities to it. This interpretation allows for **prior information** to be integrated into the inferential framework.
#
# ### Law of Large Numbers
#
# The law of large numbers states that as more observations are collected, the proportion of occurrences with a particular outcome converges to the probability of that outcome. This is why, as we roll a fair die many times, we expect the proportion of say, fives, to settle down to one-sixth. For example, if you roll a die say, 6 times, there's no guarantee that you're going to get at least one 5 in there. But if you roll the die say, 600 or 6,000 times, you would expect to see about one-sixth of the time to get a 5.

# %%
# Implementing an example to test the law of large numbers as the example above
options(repr.plot.width=10, repr.plot.height=5)
NUMBER_ROLLS <- 6000
mean_prob <- 0
chosen <- 0
vector <- numeric(0)
for (rolls in 1:NUMBER_ROLLS){
    choice <- sample(1:6, 1)
    if (choice == 5) {
        chosen <- chosen + 1
    }
    prob <- chosen/rolls
    mean_prob <- mean_prob + prob
    vector <- c(vector, prob)
}
# calculate the mean probability
# create a vector containing only mean_prob of the size NUMBER_ROLLS
mean_prob <- mean_prob/NUMBER_ROLLS
vmean_prob <- rep(mean_prob, NUMBER_ROLLS)
print(paste("Number of rolls: ", rolls))
plot(vector, type = "l", col="navy", xlab="Number of rolls", ylab="Probability", log="x")
lines(vmean_prob, type="l", lty=2, col="red")
# Out:
# [1] "Number of rolls:  6000"
# plot without title

# %% [markdown]
# ### Gambler's Fallacy
#
# The gambler's fallacy, or the law of averages is a common misunderstanding of the law of large numbers in which random processes are supposed to compensate for whatever happened in the past. So while we know that in a large number of tosses of a coin we would expect about 50% heads and 50% tails, for any given toss the probability of a head or tail is exactly 0.5, regardless of what happened in the past. Now, if you're really getting tens, or twenties of hundreds of thousands of heads in a row, at some point, you need to start thinking, maybe this is not a fair coin.

# %% [markdown]
# ### Questions
#
# 1) Which of the following events would you be most surprised by?
# &#9744; exactly 3 heads in 10 coin flips
# &#9744; exactly 3 heads in 100 coin flips
# &#9745; exactly 3 heads in 1000 coin flips

# %% [markdown]
# ---
# ## Disjoint Events + General Addition Rule

# %% [markdown]
# ### Disjoint Events
#
# Disjoint events (or mutually exclusive) are those events that cannot happen at the same time. For example, the outcome of a single coin toss cannot be a head and a tail, or a student cannot both fail and pass a class.
#
# In Venn diagram representation, where we represent each event by these circles, if events A and B are disjoint we end up with two circles that don't touch each other, which indicates that the probability of event A and B happening at the same time. So P(A and B) = 0.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/venn_disjoint.svg" width="300" align="center"/>
#
# **Non-disjoint events**
#
# Non-disjoint events on the other hand can happen at the same time. For example, a student can get an A in Statistics and Economy at the same time. A Venn diagram representation of events A and B that are non disjoint we have two circles that over lap, in other words join, which indicates that the probability of event A and B happening at the same time is a value between 0 and 1.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/venn_nondisjoint.svg" width="300" align="center"/>
#
# **Union of Disjoint Probabilities:**
#
# What we mean by union is that we're looking for the probability of one event or the other happening. So the question is **what is the probability of drawing a Jack or a 3 from a well shuffled deck of cards?** Remember, there are 52 cards in a deck, there are four Jacks and four 3s. From that, any one Jack or 3 suit.
#
# <img src="images/deck_3Jack.png" width="900" align="center"/>
#
# Therefore, the probability of drawing a Jack or a 3 is simply the sum of the individual probability of drawing a Jack or drawing a 3. Each probability is 4 over 52 resulting in a total probability of approximately of 0.154. So let's just round that and say about 15% chance.
#
# $P(3\ or\ Jack) = P(3) + P(Jack)$<br>
# $P(3\ or\ Jack) = \frac{4}{52} + \frac{4}{52}$<br>
# $P(3\ or\ Jack) = 0.0769 + 0.0769$<br>
# $P(3\ or\ Jack) = 0.1538 \approx 15\%$<br>
#
# To generalize, for disjoint events A and B, the probability of A or B happening `P(A or B)` is simply the probability of A `P(A)` plus the probability of B `P(B)`.
#
# $$
# P(A\ or\ B) = P(A) + P(B)
# $$
#
# **Union of Non-disjoint Probabilities:**
#
# Now the question is **what is the probability of drawing a Jack or a red card from a well shuffled full deck of cards?** We once again have the 4 Jacks that we saw before, but now there are 26 red cards in a deck and note that there is an overlap between them. There are two red jacks that fit both criteria and that we need to consider when calculating the probability of drawing a Jack or a red card since we don't want to double count the two red Jacks, and artificially inflate our probability of a desired outcome.
#
# <img src="images/union_jack_reds.png" width="900" align="center"/>
#
# Hence, the probability of drawing a Jack or a red card is composed by the sum of the individual probability of drawing a Jack or drawing a red card, minus the joint probability in other words, the overlap between Jacks and reds. Each probability is 4 over 52 resulting in a total probability of approximately of 0.154. So let's just round that and say about 15% chance.
#
# $P(Jack\ or\ Red) = P(Jack) + P(Red) - P(Jack\ and\ Red)$<br>
# $P(Jack\ or\ Red) = \frac{4}{52} + \frac{26}{52} - \frac{2}{52}$<br>
# $P(Jack\ or\ Red) = 0.0769 + 0.5 - 0.0384$<br>
# $P(Jack\ or\ Red) = 0.5385 \approx 54\%$<br>
#
# To generalize, for non-disjoint events A and B, the probability of A or B `P(A or B)` is the probability of A `P(A)` plus the probability of B `P(B)` minus the probability of A and B `P(A and B)` happening at the same time that we take away once to avoid double counting.
#
# $$
# P(A\ or\ B) = P(A) + P(B) - P(A\ and\ B)
# $$
#
# <img src="images/venn_AandB.png" width="200" align="center"/>
#
# Note that when A and B are disjoint, `P(A and B) = 0`, so the formula would simplify to what we saw earlier `P(A or B) = P(A) + P(B)`.
#
# ### Sample Space
#
# A sample space is a collection of all possible outcomes of a trial. For example, considering that the sex can be only male of female and a couple has two kids. It's possible that both kids are male. It's possible that both are female. It's possible that the first one is female and the second one is male or the last possibility is that the first one is male and second one is female. So if we write out all these possibilities what we have is the sample space for the two kids of this couple.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/male_female.svg" width="300" align="center"/>
#
# **Probability Distribution**
#
# A probability distribution lists all possible outcomes and the probabilities with which they occur. Let's say you toss a fair coin once, the possible outcomes are a head or a tail. Each of which has a 50% chance of happening. Alternatively, let's say you toss the coin twice. The possible outcomes are both heads, both tails, the first toss is a head and the second toss is a tail or the first toss is a tail and the second toss is a head. Since each outcome is equally likely, we have about a 25% chance of each one of them happening.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/probability_distribution.svg" width="400" align="center"/>
#
# **Rules:**
#
# Probability distributions need to follow three broad rules.
# 1. The events listed must be disjoint
# 2. Each probability must be between 0 and 1
# 3. The sum of the probabilities listed in the probability distribution must total 1
#
#
# **Complementary Events**
#
# These are two disjoint events or two mutually exclusive events, who's probabilities add up to one. For example, if a coin is toss once the complement of the `head` is a `tail`. Say a coin is toss twice the complement of the outcome `(head, head)` is simply the sum of all the other three possibilities: `(tail, tail)`, `(head, tail)` or `(tail, head)`. So what we're doing, is we're dividing the sample space into two such that, the sum of the probabilities, still add up to 1.
#
# **Disjoint vs. Complementary Events**
#
# Considering two disjoint outcomes, *Do the sum of probabilities of them always add up to one?*
# - Not necessarily! If there are more than 2 outcomes in the sample space then the probabilities of just 2 of those will not add up to 1. For example, think about running a survey in the US. Let's say you're asking people their party affiliation. They might say they're Democratic or Republican, an independent, or something else. So in this case, if we were to take any two of those outcomes from there, let's say Democrat and Republican. Thus, the sum of the probabilities of those will likely not add up to one because you're going to have other people in your sample who have voted for or who associate themselves with the other parties.
#
# Considering two complementary events, *Do the sum of probabilities of them always add up to 1?*
# - Yes! That is indeed the definition of complementary. So let's say, you're doing a coin toss again and you're looking at the probabilities of heads and tails. We know that these are complimentary events and therefore the probabilities of those are going to add up to 1.
#
# Hence, **complementary events are always necessarily disjoined** by definition. However, **disjoined events are not necessarily always complementary**.

# %% [markdown]
# ### Questions
#
# 1) What is the probability that a randomly sampled student thinks marijuana should be legalized or they agree with their parents' political views?
#
# |<td colspan="3"> Share political view |
# | :---------- | :-: | :-: | ----: |
# | Legalize MJ |  No | Yes | Total |
# | No          |  11 |  40 |    51 |
# | Yes         |  36 |  78 |   114 |
# | Total       |  47 | 118 |   165 |
#
# &#9744; $\frac{(40+36-78)}{165}$
#
# &#9745; $\frac{(114+118-78)}{165}$
#
# &#9744; $\frac{78}{165}$
#
# &#9744; $\frac{78}{188}$
#
# &#9744; $\frac{11}{47}$
#
# **Solution:**
#
# $P(Legalize=Yes\ or\ View=Yes) = P(Legalize=Yes) + P(View=Yes) - P(Legalize=Yes\ and\ View=Yes)$<br>
# $P(Legalize=Yes\ or\ View=Yes) = \frac{114}{165} + \frac{118}{165} - \frac{78}{165}$<br>
# $P(Legalize=Yes\ or\ View=Yes) = \frac{114 + 118 - 78}{165}$<br>
# $P(Legalize=Yes\ or\ View=Yes) = 0,9333 \approx 93\%$<br>
#
#
# <br>
#
# 2) In a survey, 52% of respondents said they are from Asia. Which of the following is NOT a plausible answer for what percent of the respondents in this survey are from Europe?
#
# &#9744; 48%
# &#9745; more than 48%
# &#9744; less than 48%

# %% [markdown]
# ---
# ## Independence
#
# Two processes are said to be independent if **knowing the outcome of one provides no useful information about the outcome of the other**. For example, knowing that the coin landed on a head on the first toss does not provide any useful information for determining what the coin will land on in the second toss. The probability of a head or a tail on the second toss is equally 0.5, regardless of the outcome of the first toss. Therefore, **outcomes of two coin tosses are independent**.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/independence.svg" width="800" align="center"/>
#
# On the other hand, knowing that the first card drawn from a deck is an `A` **does provide** useful information for calculating the probabilities of outcomes in the second draw.For example probability of drawing yet another `A` is going to be $\frac{3}{51}$. We have 51 cards left in the deck, and only 3 of them are `A`. While the probability of drawing a `Jack` is going to be $\frac{4}{51}$, since there still have 4 `Jacks` left in the deck. Therefore, **outcomes of two draws from a deck of cards, without replacement are dependent**.
#
# <br>
#
# **Checking for independence**
#
# If the probability of an event `A` occurring, given that event `B` occurred `P(A|B)` is the same as the probability of event `A` occurring in the first place `P(A)`, then events `A` and `B` are independent. This rule basically says that knowing `B` tells us nothing about `A`.
#
# $$
# P(A|B) = P(A)\ \ \ \ \rightarrow \ \ \ A\ \text{and}\ B\ \text{are independent.}
# $$
#
# **Practicing:**
#
# In 2013, SurveyUSA interviewed a random sample of 500 North Carolina residents, asking them whether they think widespread gun ownership protects law abiding citizens from crime, or make society more dangerous.
# - 58% of all respondents said it protects citizens.
# - 67% of white respondents,
# - 28% of black respondents,
# - and 64% of Hispanic respondents shared this view.
#
# Opinion on gun ownership and race ethnicity are most likely ...?
# &#9744; Complementary
# &#9744; Mutually exclusive
# &#9744; Independent
# &#9745; Dependent
# &#9744; Disjoint
#
# $P(\text{protect citizens}) = 0.58$<br/>
# $P(\text{protect citizens}\ |\ \text{white}) = 0.67$<br/>
# $P(\text{protect citizens}\ |\ \text{black}) = 0.28$<br/>
# $P(\text{protect citizens}\ |\ \text{hispanic}) = 0.64$<br/>
#
# <br>
#
# ### Determining Dependence Based on Sample Data
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/8a43171f/Coursera/Duke%20University/Probability-intro/Week%203/images/observed_difference.svg" width="600" align="center"/>
#
# If we observe a difference between the conditional probabilities that we calculate based on the sample, we say that these data suggest dependence. The next natural step would then be to actual conduct a hypothesis test. To see if what we observe these difference that we observed, could have just happened due to chance or natural random sampling. Or, if there's actually a real difference in the population. We can actually do a little bit of speculating based on the magnitude of the differences that we observe as well as the sample size. For example, the probability that guns protect citizens, given that somebody's white versus, given that they're black versus given that they're Hispanic, **if these conditional probabilities varied greatly, then there is stronger evidence that the difference is real**. On the other hand, **if the sample size is large, even small differences is in conditional probabilities might provide strong evidence of a real difference**.
#
# <br>
#
# **Product Rule for Independent Events**
#
# $$
# \text{If}\ A\ \text{and}\ B\ \text{are independent,}\ P(A\ \text{and}\ B) = P(A) \times P(B)
# $$
#
# For example, you toss a coin twice, then *What is the probability of getting two tails in a row?* Sounds pretty simple eh? The probability of two tails in a row is simply going to be the probability of a tail on the first toss times the probability of a tail on the second toss. Probability of tail on either toss is simply 0.5 or $\frac{1}{2}$. So the overall probability is going to be a quarter or about 25%.
#
# $P(\text{2 tails in a row}) = P(\text{tail}) \times P(\text{tail})$<br>
# $P(\text{2 tails in a row}) = \frac{1}{2} \times \frac{1}{2}$<br>
# $P(\text{2 tails in a row}) = 0.25 = 25\%$<br>
#
# A quick note, this rule isn't really limited to just two events. And it can actually be expanded to as many independent events as you need. So if, instead of doing two coin tosses, we had a hundred of them. We could simply multiply a hundred of the same probabilities together. Generically said, if `A1`, `A2` all the way through `Ak` are independent, then probability of all of these events happening at once is simply going to be the product of the individual probabilities of the events.
#
# $$
# P(A_1\ \text{and}\ A_2\ \text{and}\ A_k) = P(A_1) \times P(A_2) \times\ ...\ \times P(A_k)
# $$
#
# **Practicing:**
#
# A 2012 Gallup poll suggests that West Virginia has the highest obesity rate among US states, with 33.5% of West Virginians being obese. Assuming that the obesity rates stay constant, what is the probability that two randomly selected West Virginians are both obese?
#
# *"two individuals are randomly selected" &#8680; they are independent of each other*
#
# $P(\text{obesity}) = 0.335$<br>
# $P(\text{both obese}) = P(\text{obesity}) \times P(\text{obesity})$<br>
# $P(\text{both obese}) = 0.335 \times 0.335$<br>
# $P(\text{both obese}) \approx 0.11 \approx 11\%$<br>

# %% [markdown]
# ### Questions
#
# 1) According to a 2013 Pew Research Poll that surveyed 1,504 Americans, 67% of respondents said that they believe the Earth is warming. Roughly 50% of Republicans, 88% of Democrats, and 62% of Independents share this opinion. Based on these data, opinion on global warming and political leaning are most likely:
# &#9744; complementary
# &#9744; independent
# &#9744; mutually exclusive
# &#9745; dependent
# &#9744; disjoint
#
# *Explaning:* The probability that someone believes the Earth is warming varies by their political affiliation, hence political affiliation and believing that the Earth is warming appear to be dependent. If they were independent, the conditional probabilities of believing that the Earth is warming would be the same given each political affiliation.
#
# $P(\text{global warming}) = 0.67$<br/>
# $P(\text{global warming}\ |\ \text{Republican}) = 0.5$<br/>
# $P(\text{global warming}\ |\ \text{Democrats}) = 0.88$<br/>
# $P(\text{global warming}\ |\ \text{Independent}) = 0.62$<br/>
#
# 2) Earlier we saw that `P(protects citizens | White) = 0.67` and `P(protects citizens | Hispanic) = 0.64`. Under which sample size would you be more convinced of a real difference between the proportions of Whites and Hispanics who think the widespread gun ownership protects citizens?
# &#9744; n = 500
# &#9745; n = 50,000
#
# 3) In a multiple-choice exam, there are 5 questions and 4 choices for each question (a, b, c, d). You have not studied at all and decide to randomly guess the answers. What is the probability that you get all 5 questions correct?
# &#9745; $0.25^5 \approx 0.00098$
# &#9744; $0.2^4 = 0.0016$
# &#9744; $0.5^5 = 0.03125$
# &#9744; $0.25\times 5 = 1.25$
# &#9744; $\frac{4}{5} = 0.8$
#
# $P(\text{correct}) = \frac{1}{4} = 0.25$<br>
# $P(\text{5 correct}) = P(\text{correct}_1) \times P(\text{correct}_2) \times\ ...\ \times P(\text{correct}_5)$<br>
# $P(\text{5 correct}) = P(\text{correct})^5$<br>
# $P(\text{5 correct}) = 0.25^5 \approx 0.00098$<br>

# %% [markdown]
# ---
# ## Examples
#
# 1) The World Values Survey is an ongoing worldwide survey that polls the world population about perceptions of life, work, family, politics, etc. The most recent phase of the survey that polled 77,882 people from 57 countries estimates that 36.2% of the world's population agree with the statement "Men should have more right to a job than women". The survey also estimates that 13.8% of people have a university degree or higher and that 3.6% of people fit both criteria.
#
# I) Are agreeing with the statement, men should more right to a job than women, and having a university degree or higher disjoint events?
#
# <span style="color:navy">
# $P(\text{agree}) = 0.362$<br>
# $P(\text{university}) = 0.138$<br>
# $P(\text{agree & university}) = 0.036$<br>
# </span>
# <span style="color:navy">
# *Since the probability of agreeing with this statement and having a university degree or higher is not 0, the events are not disjoint.*
# </span>
#
# II) Draw a Venn diagram summarizing the variables and their associated probabilities.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/7ed7f93a/Coursera/Duke%20University/Probability-intro/Week%203/images/venn_agree_uni.svg" width="250" align="center"/>
#
# <span style="color:navy">
# $\text{Venn_agree} = P(\text{agree}) - P(\text{agree & university})$<br>
# $\text{Venn_agree} = 0.362 - 0.036$<br>
# $\text{Venn_agree} = 0.326$<br>
# </span>
#
# <span style="color:navy">
# $\text{Venn_university} = P(\text{university}) - P(\text{agree & university})$<br>
# $\text{Venn_university} = 0.138 - 0.036$<br>
# $\text{Venn_university} = 0.102$<br>
# </span>
#
# III) What is the probability that a randomly drawn person has a university degree or higher or agrees with the statement about men having more right to a job than women?
#
# <span style="color:navy">
# Following the general rule $P(A\ or\ B) = P(A) + P(B) - P(A\ \&\ B)$ we have:
# </span>
#
# <span style="color:navy">
# $P(\text{university or agree}) = P(\text{university}) + P(\text{agree}) - P(\text{agree & university})$<br>
# $P(\text{university or agree}) = 0.138 + 0.362 - 0.036$<br>
# $P(\text{university or agree}) = 0.464$<br>
# </span>
#
# <span style="color:navy">
# Or considering the Venn diagram, we sum the values presented in it to achieve the same result.
# </span>
#
# <span style="color:navy">
# $P(\text{university or agree}) = 0.326 + 0.036 + 0.102$<br>
# $P(\text{university or agree}) = 0.464$<br>
# </span>
#
# IV) What percent of the world population do not have a university degree and disagree with the statement about men having more right to a job than women?
#
# <span style="color:navy">
# $P(\text{neither agree nor university}) = 1 - P(\text{agree or university})$<br>
# $P(\text{not university}) = 1 - 0.464$<br>
# $P(\text{not university}) = 0.536$<br>
# </span>
#
# V) Does it appear that the event that someone agrees with the statement is independent of the event that they have a university degree or higher?
#
# <span style="color:navy">
# We can check the product rule that says if A and B are independent, probability of A and B is equal to probability of A times probability of B. If A and B are independent, $P(A\ and\ B) = P(A) \times P(B)$. Thus,
# </span>
#
# <span style="color:navy">
# $P(\text{agree & university}) = 0.036$<br>
# $P(\text{agree & university}) = P(\text{agree}) \times P(\text{university})$<br>
# $P(\text{agree & university}) = 0.362 \times 0.138$<br>
# $P(\text{agree & university}) = 0.0499 \rightarrow \neq 0.036$<br>
# </span>
#
# <span style="color:navy">
# Events are **NOT independent**!
# </span>
#
# VI) What is the probability that at least 1 in 5 randomly selected people agree with the statement about men having more right to a job than women?
#
# <span style="color:navy">
# If selecting 5 people randomly, our sample space for the number of people who might agree with this statement range from 0 to 5. It is possible that none of them agree, just one agrees, two agree, etc., all the way to all five agree. We're interested in instances where at least one person agrees with this statement. So we can divide up the sample space into two complimentary events, none indicated by the 0 and at least 1 which covers all possible outcomes from 1 through 5. To find the probability of at least 1 out of 5 people agreeing with the statement, we simply subtract the probability of its complement, none agree, from 1. So that is 1 minus the probability of all of them disagreeing.
# </span>
#
# <span style="color:navy">
# $P(\text{agree}) = 0.362$<br>
# $S = \{0, 1, 2, 3, 4, 5\} \rightarrow S = \{0, \text{<at least 1>}\}$<br>
# $P(\text{at least 1 agree}) = 1 - P(\text{none agree})$<br>
# $P(\text{at least 1 agree}) = 1 - P(D\ D\ D\ D\ D)$<br>
# </span>
#
# <span style="color:navy">
# First we need to figure out what is the probability that any given person disagrees with the statement? That is also going to be a complement, and it's the complement of the probability of agreeing.
# </span>
#
# <span style="color:navy">
# $P(\text{disagree}) = 1 - P(\text{agree})$<br>
# $P(\text{disagree}) = 1 - 0.362$<br>
# $P(\text{disagree}) = 0.638$<br>
# </span>
#
# <span style="color:navy">
# Plugging that back into the formula, we have 1 minus 0.638 to the 5th power. We can multiply each one of these probabilities because we know that whether one person in our group disagrees with the statement is independent of another because we're randomly sampling them.
# </span>
#
# <span style="color:navy">
# $P(\text{at least 1 agree}) = 1 - P(D\ D\ D\ D\ D)$<br>
# $P(\text{at least 1 agree}) = 1 - 0.638^5$<br>
# $P(\text{at least 1 agree}) = 1- 0.1057$<br>
# $P(\text{at least 1 agree}) = 0.8943$<br>
# </span>

# %% [markdown]
# ### Questions
#
# 1) Given the probabilities below and the accompanying Venn diagram, what percent of the world population have a university degree or higher and disagree with the statement about men having more right to a job than women?
#
# <img src="images/venn_q1.png" width="300" align="center"/>
#
# $P(agree) = 0.362
# $P(uni. degree) = 0.138
# P(agree & uni. degree) = 0.036
#
# &#9744; $1 - 0.138 = 0.862 \rightarrow 86.2\%$
# &#9745; $0.102 \rightarrow 10.2\%$
# &#9744; $0.326 \rightarrow 32.6\%$
# &#9744; $0.362 + 0.138 = 0.5 \rightarrow 50\%$
#
# 2) Given that 36.2% of the world population agrees with the statement about men having more right to a job than women, what is the probability that in a random sample of 5 randomly selected people all of them agree with the statement?
# &#9745; $0.362^5 \approx 0.006$
# &#9744; $0.362 \times 5 = 1.81$
# &#9744; $\frac{0.362}{5} = 0.0724$
#
# *Solving:*
# $P(\text{agree}) = 0.362$<br>
# $P(\text{5 agree}) = P(\text{agree}_1 \text{and agree}_2 \text{and agree}_3 \text{and agree}_4 \text{and agree}_5)$<br>
# $P(\text{5 agree}) = P(\text{agree}_1) \times P(\text{agree}_2) \times P(\text{agree}_3) \times P(\text{agree}_4) \times P(\text{agree}_5)$<br>
# $P(\text{5 agree}) = 0.362^5$<br>
# $P(\text{5 agree}) = 0.0062$<br>
#
# 3) Given that 13.8% of the world population have a university degree or higher, what is the probability that in a random sample of 3 people at least one person has a university degree or higher?
# &#9744; $1 - 0.138 = 0.862$
# &#9744; $1 - 0.1383 \approx 0.997$
# &#9745; $1 - (1 - 0.138)^3 \approx 0.359$
# &#9744; $(1 - 0.138)^3 \approx 0.641$
# &#9744; $0.138 \times 3 = 0.414$
#
# *Solving:*
# $P(\text{university}) = 0.138$<br>
# $S = \{0, 1, 2, 3\} \rightarrow S = \{0, \text{<at least 1>}\}$<br>
# $P(\text{at least 1}) = 1 - P(\text{none has university})$<br>
# $P(\text{at least 1}) = 1 - P(\text{NU NU NU})$ #NU : no univesity<br>
# $P(\text{no university}) = 1 - P(\text{university})$<br>
# $P(\text{no university}) = 1 - 0.138$<br>
# $P(\text{no university}) = 0.862$<br>
# $P(\text{NU NU NU}) = P(\text{no university})^3$<br>
# $P(\text{NU NU NU}) = 0.6405$<br>
# $P(\text{at least 1}) = 1 - P(\text{NU NU NU})$<br>
# $P(\text{at least 1}) = 1 - 0.6405$<br>
# $P(\text{at least 1}) = 0.3594$<br>

# %% [markdown]
# ## Spotlight: Disjoint vs. Indpendent Events
#
# Two events that are disjoint cannot happen at the same time. While two processes are independent if knowing the outcome of one provides no useful information about the outcome of the other. So disjointness is about events happening at the same time. So if events `A` and `B` are **disjoint**,
#
# $$P(A\ and\ B) = 0$$
#
# While independence is about processes not affecting each other. So if events `A` and `B` are **independent**,
#
# $$P(A\ |\ B) = P(A)$$
#
# Say we're interested in the eye color of babies. And the only possibilities are:
# - blue
# - green
# - brown
#
# Suppose there's one baby, the possible eye colors are blue, green, and brown. These outcomes are **disjoints, since they can not happen at the same time**.
#
# Now suppose there are two babies, and suppose that we know that the first one has brown eyes. The possibilities for the second one are, again, blue, green, and brown. These three outcomes for the second baby are also disjoint from each other. However, the eye color of the first and second baby may be dependent or independent depending on whether the babies are related or randomly drawn from the population. If the babies are related and we know that one has brown eyes, the other one is going to be more likely to also have brown eyes. But if not related and they're randomly drawn from the population, the fact that the first one has brown eyes will not provide any useful information about the second one having blue eyes.
#
# One last item to note is that the disjoint outcomes, the color of one baby's eyes, blue, green, or brown, are also **dependent** on each other. Because if we know that the baby has blue eyes, we also know that it doesn't have green or brown eyes. We can generalize this to say that **disjoint events with non-zero probability are always dependent on each other**. Because if we know that one happened, we know that the other one cannot happen.
#
# <img src="https://cdn.rawgit.com/rogergranada/MOOCs/b30300c5/Coursera/Duke%20University/Probability-intro/Week%203/images/disjoint_independent.svg" width="800" align="center"/>

# %% [markdown]
# ### Questions
#
# 1) Which of the following is true? Assume a fair coin.
# &#9744; Outcomes of one coin toss are disjoint and independent; outcomes of two coin tosses are dependent.
# &#9745; Outcomes of one coin toss are disjoint and dependent; outcomes of two coin tosses are independent.
# &#9744; Outcomes of one coin toss are disjoint and dependent; outcomes of two coin tosses are also dependent.
