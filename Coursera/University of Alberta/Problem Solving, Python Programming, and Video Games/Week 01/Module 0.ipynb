# %% [markdown]
# # Introduction
#
# In Module 0, you will meet the instructional team and be introduced to the four themes of this course: computer science, problem solving, Python programming, and how to create video games.
#
# **KEY CONCEPTS**
#
# - Recall the four themes of the course: how to compute with information, how to solve problems, how to program in Python, and how to create video games.
# - Recall that there are many different types of information.
# - Recall that an algorithm is the way that a computation is performed.
# - Recall that a programming language needs an interpreter or compiler to translate it to machine language.
# - Recall the specific learning outcomes for this course.
# - Recognize the difference between problem-based and traditional topic-based learning.
# - Recognize how teamwork will be simulated in this course.
# - Recall our suggestions for success.

# %% [markdown]
# ## Quiz
#
# **1. Which of the following are themes for this course?**
#
# &#9744; Using multiple operating systems<br>
# &#9745; Writing Python programs<br>
# &#9745; Creating video games<br>
# &#9744; Creating databases<br>
# &#9745; Computer science concepts<br>
# &#9745; Solving problems that require computation<br>
# &#9744; Creating web pages<br>
# &#9744; Writing Java programs<br>
#
#
# **2. Which of the following are types of information that computation can be applied to?**
#
# &#9744; communicate<br>
# &#9745; strings<br>
# &#9744; acquire<br>
# &#9744; represent<br>
# &#9745; audio<br>
# &#9745; numbers<br>
# &#9744; generate<br>
# &#9744; transform<br>
# &#9745; text<br>
# &#9745; video<br>
#
# **3. Which of the following are examples of algorithms?**
#
# &#9745; Watch television: turn on the television, change channels, adjust the volume<br>
# &#9744; Drive a car: wheels, engine, windows<br>
# &#9744; Bake a cake: flour, eggs, oven<br>
# &#9744; Wash hair: shampoo, water, hair<br>
# &#9745; Get dressed: put on socks, put on pants, put on shirt, put on shoes<br>
# &#9745; Buy food: buy milk, buy bread, buy cheese, buy vegetables<br>
# &#9744; Sit down: chair, stool, sofa<br>
#
# **4. Which of the following are examples of interpretation?**
#
# &#9744; Divide an orange into segments and eat one segment at a time<br>
# &#9744; Convert dollars into pesos and spend a few at a time<br>
# &#9745; Read a poem and explain what each line means<br>
# &#9744; Write a video game program one statement at a time<br>
# &#9745; Convert a Python program into machine instructions and evaluate them one statement at a time<br>
# &#9745; Translate spoken English into French one phrase at a time<br>
#
# **5. Which of the following are learning objectives for this course?**
#
# &#9744; Translate a Python program into machine instructions<br>
# &#9744; Translate a Python program into a Java program<br>
# &#9745; Use several different types of Python data<br>
# &#9745; Evaluate the quality of Python programs<br>
# &#9745; Identify concerns about problem solutions<br>
# &#9744; Build a birdhouse<br>
# &#9745; Create algorithms that are programming language independent<br>
# &#9745; Write a test plan before writing a program<br>
# &#9744; Write a test plan for code immediately after writing that code
#
# **6. Which of the following demonstrates problem-based learning?**
#
# &#9744; Learn to program in Python by covering these topics: names and namespaces, simple data types, input and output, and functions, and then writing your first program<br>
# &#9744; Learn to play tennis by reading the rules first, then watching a video about how to hold a racket, how to swing a racket, and how to serve, and finally trying to play a tennis game<br>
# &#9745; Learn to speak English by watching English cartoons on television, trying to figure out the meaning of words based on what is happening, and asking someone when you can't figure out what a particular word means<br>
# &#9745; Learn to swim by jumping in waist-high water, trying to float, then trying to swim, and asking someone for help when you stop making progress
#
# **7. Which of the following techniques will be used to simulate teamwork in this course?**
#
# &#9745; Demonstrating a game to you before you create the game<br>
# &#9744; Using video games as examples to learn to program<br>
# &#9744; Entering code in a Python shell to see how it works<br>
# &#9745; Using a Description Builder to create a game description<br>
# &#9745; Providing you with the game features that should be in each version<br>
# &#9744; Playing a game before you try to create it<br>
#
# **8. Which of the following are suggestions from the instructional team to increase your chances of success in this course?**
#
# &#9744; If you unsure of a concept, search the course discussion forums about the topic, but don't ask a question since other learners may realize you don't understand<br>
# &#9745; Use the debugger to understand your programs<br>
# &#9744; Find someone else in the course and compete with that individual to see who can score the highest on the quizzes<br>
# &#9745; Practice by experimenting with small program changes<br>
# &#9745; Make many mistakes when trying to figure out how code works<br>
# &#9744; If you are having difficulty with a programming concept, rewatch the videos several times instead of entering some code to see what happens
