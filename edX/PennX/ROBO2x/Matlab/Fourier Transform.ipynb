% %% [markdown]
% # Apply Fourier Transform in a signal

% %%
support = 16;
sigma = 2;
# vec = [-7 -6 -5 ... 6 7 8]
vec = -floor(support/2)+1:floor(support/2);
# applies gaussian on the vector
gaussian = (1/(sigma*sqrt(2*pi)))*exp(-d.^2/(2*sigma^2));

figure(1)
stem(d,g);

figure;
stem(d,abs(fft(g)));

% %% [markdown]
% # Reconstruct the original signal

% %%
figure;
stem(d,abs(fftshift(g, 1)));

% %%
support = 16;
sigma = 2;
# vec = [-7 -6 -5 ... 6 7 8]
vec = -floor(support/2)+1:floor(support/2);
# applies gaussian on the vector
gaussian = sin(vec)

figure(1)
stem(d,gaussian);

figure;
stem(d,abs(fft(gaussian)));
% Out:
% gaussian =
%
%  Columns 1 through 8:
%
%   -0.65699   0.27942   0.95892   0.75680  -0.14112  -0.90930  -0.84147   0.00000
%
%  Columns 9 through 16:
%
%    0.84147   0.90930   0.14112  -0.75680  -0.95892  -0.27942   0.65699   0.98936
